# %%
import pandas as pd
import requests

# %%
sp500_tick=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
print(sp500_tick[1])
# Out:
#                   Date  Added                       Removed                   \
#                   Date Ticker              Security  Ticker         Security
# 0        March 2, 2022    MOH     Molina Healthcare    INFO       IHS Markit
# 1    February 15, 2022   NDSN               Nordson    XLNX           Xilinx
# 2     February 3, 2022    NaN                   NaN     GPS              Gap
# 3     February 2, 2022    CEG  Constellation Energy     NaN              NaN
# 4    December 20, 2021   SBNY        Signature Bank     LEG  Leggett & Platt
# ..                 ...    ...                   ...     ...              ...
# 286   December 5, 2000    SBL   Symbol Technologies      OI   Owens-Illinois
# 287   December 5, 2000    AYE      Allegheny Energy     GRA         WR Grace
# 288   December 5, 2000    ABK       Ambac Financial     CCK   Crown Holdings
# 289      July 27, 2000   JDSU          JDS Uniphase     RAD          RiteAid
# ...

# %%
ans=requests.get('https://sec.report/Ticker/ADBE',headers={'user-agent':'Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'})
re=pd.read_html(ans.text)
print(re[5])
# Out:
#                     0                                                  1   2  \
# 0     Bryan S. Lamkin  Executive Vice President and General Manager, ... NaN
# 1      John F. Murphy  Executive Vice President and Chief Financial O... NaN
# 2    Matthew Thompson  Executive Vice President, Worldwide Field Oper... NaN
# 3    Shantanu Narayen  Chairman of the Board, President and Chief Exe... NaN
# 4   Anil Chakravarthy  Executive Vice President and General Manager, ... NaN
# 5          Ann Lewnes  Executive Vice President and Chief Marketing O... NaN
# 6        Donna Morris  Chief Human Resources Officer and Executive Vi... NaN
# 7    Mark S. Garfield  Vice President, Chief Accounting Officer and C... NaN
# 8      Abhay Parasnis  Chief Technology Officer and Executive Vice Pr... NaN
# 9        Scott Belsky  Chief Product Officer and Executive Vice Presi... NaN
# 10           Dana Rao  Executive Vice President, General Counsel and ... NaN
# ...

# %%
ans=requests.get('https://sec.report/Document/0000320193-21-000063/',headers={'user-agent':'Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'})
re=pd.read_html(ans.text)
print(re)
# Out:
# [    0   1   2
# 0 NaN NaN NaN
# 1 NaN NaN NaN,     0   1   2
# 0 NaN NaN NaN
# 1 NaN NaN NaN,     0   1   2
# 0 NaN NaN NaN
# 1 NaN NaN NaN,                                                0   \
# 0                                             NaN
# 1                                      California
# 2  (State or other jurisdiction of incorporation)
#
#                                                1   \
# 0                                             NaN
# 1                                      California
# 2  (State or other jurisdiction of incorporation)
#
#                                                2   3   4   5   \
# 0                                             NaN NaN NaN NaN
# 1                                      California NaN NaN NaN
# 2  (State or other jurisdiction of incorporation) NaN NaN NaN
#
#                          6                         7   \
# 0                       NaN                       NaN
# 1                 001-36743                 001-36743
# ...
